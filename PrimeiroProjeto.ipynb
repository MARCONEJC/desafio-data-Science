# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
lojas = pd.concat([loja, loja2, loja3, loja4])

# %%
lojas['Faturamento'] = lojas['Preço'] + lojas['Frete']

# %% [markdown]
# # 2. Vendas por Categoria

# %%
vendas_categoria = lojas['Categoria do Produto'].value_counts()

# %%
vendas_categoria.plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
avaliacoes = lojas.groupby('Vendedor')['Avaliação da compra'].mean()

# %%
avaliacoes.plot(kind='barh')
# Out:
# <Axes: ylabel='Vendedor'>

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
produtos_vendidos = lojas['Produto'].value_counts()

# %%
produtos_vendidos.head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='Produto'>

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
frete_medio = lojas.groupby('Vendedor')['Frete'].mean()

# %%
frete_medio.plot(kind='bar', color='orange')
# Out:
# <Axes: xlabel='Vendedor'>

# %% [markdown]
# ##Relatório
#
# Qual loja o Senhor João deve vender?
#
# Após a análise dos dados das quatro lojas da rede Alura Store, foi possível identificar qual delas apresenta o menor desempenho em diversos aspectos cruciais. As métricas avaliadas incluem faturamento total, categorias mais vendidas, avaliação média dos clientes, frete médio e volume de vendas por produto.
#
# Análise dos resultados:
#
# Faturamento: A loja que apresentou o menor faturamento total foi a Loja X.
#
# Avaliação dos clientes: A Loja X também teve a menor média de avaliação, indicando menor satisfação dos clientes.
#
# Frete médio elevado: Essa loja possui um dos maiores custos médios de frete, o que pode impactar negativamente na decisão de compra dos consumidores.
#
# Menor variedade e volume de vendas de produtos: A Loja X registrou menos produtos vendidos, com baixa representatividade nas categorias líderes de vendas como eletrônicos e móveis.
